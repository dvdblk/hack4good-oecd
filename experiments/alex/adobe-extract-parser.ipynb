# %% [markdown]
# # Adobe Extract API parser

# %%
# !pip install pdfservices-sdk

# %%
from adobe.pdfservices.operation.auth.credentials import Credentials
from adobe.pdfservices.operation.execution_context import ExecutionContext
from adobe.pdfservices.operation.io.file_ref import FileRef
from adobe.pdfservices.operation.pdfops.extract_pdf_operation import ExtractPDFOperation
from adobe.pdfservices.operation.pdfops.options.extractpdf.extract_pdf_options import (
    ExtractPDFOptions,
)
from adobe.pdfservices.operation.pdfops.options.extractpdf.table_structure_type import (
    TableStructureType,
)
from adobe.pdfservices.operation.pdfops.options.extractpdf.extract_element_type import (
    ExtractElementType,
)
from adobe.pdfservices.operation.exception.exceptions import ServiceApiException, ServiceUsageException

import os.path
import zipfile
import json

import dotenv

from dataclasses import dataclass
from typing import Any, Dict, List, Optional, Set, Tuple, Union
from enum import StrEnum
from dataclasses import dataclass
import weakref
import re
from pathlib import Path

# %%
# Get environment variables
dotenv.load_dotenv()

client_id = os.getenv("ADOBE_CLIENT_ID")
client_secret = os.getenv("ADOBE_CLIENT_SECRET")

# Some constants
# Input PDF file
input_pdf = "UK_23.pdf"

# Input PDF directory
input_pdf_dir = "/Users/dvdblk/Downloads/pdf_files_complete/"
input_pdf_path = os.path.join(input_pdf_dir, input_pdf)
# Output directory
out_dir = "../../data/interim/000-adobe-extract/"
# Output filename will be the same as input but extension will be .zip

# %%
@dataclass
class AdobeExtractedPDF:
    json_data: Dict[str, Any]
    file_path: str
    csv_tables: Dict[str, List[str]]

def get_extracted_pdf(input_file_path: str) -> AdobeExtractedPDF:
    input_basename = Path(input_pdf).stem
    # Check if .zip file exists
    zip_file = os.path.join(out_dir, f"{input_basename}.zip")

    if os.path.isfile(zip_file):
        print(f"File '{zip_file}' already exists, skipping download.")

        # Open and read zip file
        archive = zipfile.ZipFile(zip_file, "r")
        json_data = archive.open("structuredData.json").read()
        json_data = json.loads(json_data)

        # Extract csv tables
        csv_tables = {}
        table_files = [file_name for file_name in archive.namelist() if file_name.startswith("tables/")]
        for table_name in table_files:
            csv_tables[table_name] = archive.open(table_name).read().decode("utf-8-sig").rstrip("\n")

        return AdobeExtractedPDF(json_data, zip_file, csv_tables)

    # Initial setup, create credentials instance.
    credentials = (
        Credentials.service_principal_credentials_builder()
        .with_client_id(client_id)
        .with_client_secret(client_secret)
        .build()
    )

    # Create an ExecutionContext using credentials and create a new operation instance.
    execution_context = ExecutionContext.create(credentials)
    extract_pdf_operation = ExtractPDFOperation.create_new()

    # Set operation input from a source file.
    source = FileRef.create_from_local_file(input_file_path)
    extract_pdf_operation.set_input(source)

    # Build ExtractPDF options and set them into the operation
    extract_pdf_options: ExtractPDFOptions = (
        ExtractPDFOptions.builder().with_elements_to_extract([ExtractElementType.TEXT, ExtractElementType.TABLES]).with_table_structure_format(TableStructureType.CSV).build()
    )
    extract_pdf_operation.set_options(extract_pdf_options)

    # Execute the operation.
    result: FileRef = extract_pdf_operation.execute(execution_context)

    # Save the result to the specified location.
    result.save_as(zip_file)

    # Extract json file and save to out_dir
    archive = zipfile.ZipFile(zip_file, "r")
    json_data = archive.open("structuredData.json").read()
    json_data = json.loads(json_data)

    # Extract csv tables
    csv_tables = {}
    table_files = [file_name for file_name in archive.namelist() if file_name.startswith('tables/')]
    for table_name in table_files:
        csv_tables[table_name] = archive.open(table_name).read().decode("utf-8")

    return AdobeExtractedPDF(json_data, zip_file, csv_tables)

# %%
extracted_pdf = get_extracted_pdf(input_file_path=input_pdf_path)

result = extracted_pdf.json_data
# Out:
# File '../../data/interim/000-adobe-extract/UK_23.zip' already exists, skipping download.

# %%
print(extracted_pdf.csv_tables)
# Out:
# {'tables/fileoutpart0.csv': 'There are two tools for exploring the dynamics of change  • Driver Mapping   • Axes of Uncertainty    ,➲  Chapter 7  ', 'tables/fileoutpart2.csv': 'Tool overview  ,Use it to  ,Time required  \n"Driver mapping  is used to identify the political, economic, societal, technological, legislative and environmental (PESTLE) drivers shaping the future policy environment  ",• identify drivers shaping the future   • identify which drivers are most important for the future of the policy area or strategic endeavour   • distinguish between certain and uncertain outcomes resulting from the action of drivers    ,• 1.5 to 2 hours in a workshop setting   • 45 to 60 minutes for a small team discussion    \nAxes of uncertainty  are used to define the critical uncertainties for the policy area in the future and to frame the scenarios  ,• characterize the nature of the critical uncertainties facing the policy area in the future   • agree which critical uncertainties are most important   • create a meaningful and focused scenario matrix    ,• 90 minutes  ', 'tables/fileoutpart18.csv': ',The Issues Paper  The Issues Paper presents quotes from the 7 Questions interviews to illustrate the strategic issues and choices around the policy area  \nAims:  ,➲ To set out the main ideas and issues surrounding the policy area that were identified in the interview programme   ➲ To identify the emerging themes that need to be tackled   ➲ To highlight conflicting views of the future and expectations of the policy   ➲ To highlight the potential trade offs and choices that policy design will need to address    \nApproach:  ,Select key quote from the interviews and organise them by theme  \nParticipants:  ,The Issues Paper is developed by the project team  \nTiming:  ,Varies – can take several weeks  \nFacilitation:  ,Advanced beginner  \nOutput:  ,An Issues Paper (or slides) that capture different perspectives of what success in the future will be like and what needs to be done to achieve it  \nOutcome:  ,Qualitative analysis of stakeholder perspectives and of the strategic challenges and choices or policy development  \nGood for:  ,➲ Providing a snapshot of current thinking and different perspectives   ➲ Highlighting areas of agreement and disagreement   ➲ Highlighting sensitive issues    \nRisk:  ,Medium. Some issues raised in the interview programme may be politically sensitive and may need to be handled carefully  ', 'tables/fileoutpart22.csv': 'Number:  ,Works best with groups of 12 or more – but can be done with fewer  \nTiming:  ,1.5 to 2 hours in a workshop setting 45 to 60 minutes for a small team discussion  \nFacilitation:  ,Advanced beginner  ', 'tables/fileoutpart47.csv': 'Purpose:  ,To provide Health Education England (HEE) with the evidence it needs to underpin its workforce development strategies and long-term investment decisions  \nTools:  ,Horizon Scanning; Evidence Base Development; Demand Driver Mapping  \nResources:  ,"Ongoing internal programme with approximately 2 FTE, although this varies as staff members have other responsibilities. Some access to analytical staff to support specific work programmes  "\nSponsors:  ,Director of Strategy; Director of Workforce Intelligence  \nOutputs:  ,HEE’s Strategic Framework  Internal Horizon Scanning Bulletin (produced bi-monthly shared across HEE’s national and local offices)  Weekly Alert Scanning (currently shared within Strategy Team to identify areas for further investigation)  Evidence Base (ongoing development for reference purposes)  \nSuccesses:  ,Development and adoption of HEE’s Strategic Framework (see above) with excellent national and international feedback.  Production and dissemination of HEE’s internal Horizon Scanning Bulletin with excellent feedback  \nChallenges:  ,Difficult to get people to lift their heads from firefighting current issues in order to focus on future opportunities  Finding sufficient robust quantitative research to build into our analysis ...

# %%
# Print path, page, text and table file paths for each element in the result document
for element in result["elements"]:
    print("Path: " + element["Path"])
    if page := element.get("Page"):
        print("Page: " + str(element["Page"]))
    if text := element.get("Text"):
        print("Text: " + element["Text"])
    if file_paths := element.get("filePaths"):
        print("File paths: " + str(file_paths))
    print()
# Out:
# Path: //Document/Figure
#
# Path: //Document/P
# Text: The Futures Toolkit
#
# Path: //Document/Figure[2]
#
# Path: //Document/P[2]
# Text: Tools for Futures Thinking and Foresight Across UK Government
#
# Path: //Document/P[3]
# Text: Edition 1.0
#
# Path: //Document/P[4]
# Text: November 2017
#
# Path: //Document/Figure[3]
#
# Path: //Document/H1
# Page: 1
# Text: Contents
#
# Path: //Document/TOC/TOCI/Reference/Lbl
# Page: 1
# Text: 1.
#
# Path: //Document/TOC/TOCI/Reference/LBody
# Page: 1
# Text: Introduction .............................................................................................................................. 1
#
# Path: //Document/TOC/TOCI[2]/Reference/Lbl
# Page: 1
# Text: 2.
#
# Path: //Document/TOC/TOCI[2]/Reference/LBody
# Page: 1
# Text: Introduction to futures thinking.............................................................................................. 2
#
# Path: //Document/TOC/TOCI[3]/Reference/Lbl
# Page: 1
# Text: 3.
#
# Path: //Document/TOC/TOCI[3]/Reference/LBody
# Page: 1
# Text: Futures process design ........................................................................................................... 6
#
# Path: //Document/TOC/TOCI[4]/Span
# Page: 1
# Text: 4.
#
# Path: //Document/TOC/TOCI[4]/Span[2]/Reference
# Page: 1
# Text: Using the toolkit ....................................................................................................................... 8
#
# Path: //Document/TOC/TOCI[5]/Reference/Lbl
# Page: 1
# Text: 5.
#
# Path: //Document/TOC/TOCI[5]/Reference/LBody
# Page: 1
# Text: Pathways designed to meet specific business needs........................................................ 15
#
# Path: //Document/TOC/TOCI[6]/Span/Reference
# Page: 1
# Text: Pathway 1: Exploring underlying issues or causes when scoping or defining a policy area... 16
#
# Path: //Document/TOC/TOCI[7]/Span/Reference
# Page: 1
# Text: Pathway 2: Determining a vision for a new policy area ........................................................... 17
#
# Path: //Document/TOC/TOCI[8]/Span/Reference
# Page: 1
# Text: Pathway 3: Testing policy options for an existing policy area under time constraints ............ 18
#
# Path: //Document/TOC/TOCI[9]/Span/Reference
# Page: 1
# Text: Pathway 4: Testing policy options for a policy area................................................................. 19
#
# Path: //Document/TOC/TOCI[10]/Span/Reference
# Page: 1
# Text: Pathway 5: Exploring and communicating the complexity of a situation ................................ 20
#
# Path: //Document/TOC/TOCI[11]/Span/Reference
# Page: 1
# Text: Pathway 6: Identifying futures research and evidence priorities ............................................. 22
#
# Path: //Document/TOC/TOCI[12]/Span/Reference
# Page: 1
# Text: Pathway 7: Identifying and prioritising future opportunities and threats for action ................. 24
#
# Path: //Document/TOC/TOCI[13]/Reference/Lbl
# Page: 1
# Text: 6.
#
# Path: //Document/TOC/TOCI[13]/Reference/LBody
# Page: 1
# Text: Tools for gathering intelligence about the future................................................................ 26
#
# Path: //Document/TOC/TOCI[14]/Span/Reference
# Page: 1
# Text: Horizon Scanning..................................................................................................................... 27
#
# Path: //Document/TOC/TOCI[15]/Span
# Page: 1
# Text: 7
#
# Path: //Document/TOC/TOCI[15]/Span[2]/Reference
# Page: 1
# Text:  Questions.............................................................................................................................. 29
#
# Path: //Document/TOC/TOCI[16]/Span/Reference
# Page: 1
# Text: The Issues Paper ..................................................................................................................... 33
#
# Path: //Document/TOC/TOCI[17]/Span/Reference
# Page: 1
# Text: Delphi ....................................................................................................................................... 35
#
# Path: //Document/TOC/TOCI[18]/Reference/Lbl
# Page: 1
# Text: 7.
#
# Path: //Document/TOC/TOCI[18]/Reference/LBody
# Page: 1
# Text: Tools for exploring the dynamics of change ....................................................................... 41
#
# Path: //Document/TOC/TOCI[19]/Span/Reference
# Page: 1
# Text: Driver Mapping ........................................................................................................................ 42
#
# Path: //Document/TOC/TOCI[20]/Span/Reference
# Page: 1
# Text: Axes of Uncertainty.................................................................................................................. 46
#
# Path: //Document/TOC/TOCI[21]/Reference/Lbl
# Page: 1
# Text: 8.
#
# Path: //Document/TOC/TOCI[21]/Reference/LBody
# Page: 1
# Text: Tools for describing what the future might be like ............................................................. 50
#
# Path: //Document/TOC/TOCI[22]/Span/Reference
# Page: 1
# Text: Scenarios ................................................................................................................................. 51
#
# Path: //Document/TOC/TOCI[23]/Span/Reference
# Page: 1
# Text: Visioning................................................................................................................................... 57
#
# Path: //Document/TOC/TOCI[24]/Span/Reference
# Page: 1
# Text: SWOT Analysis ........................................................................................................................ 61
#
# Path: //Document/TOC/TOCI[25]/Reference/Lbl
# Page: 1
# Text: 9.
#
# Path: //Document/TOC/TOCI[25]/Reference/LBody
# Page: 1
# Text: Tools for developing and testing policy and strategy......................................................... 63
#
# Path: //Document/TOC/TOCI[26]/Span/Reference
# Page: 1
# Text: Policy Stress-testing ................................................................................................................ 64
#
# Path: //Document/TOC/TOCI[27]/Span/Reference
# Page: 1
# Text: Backcasting ............................................................................................................................. 68
#
# Path: //Document/TOC/TOCI[28]/Span/Reference
# Page: 1
# Text: Roadmapping .......................................................................................................................... 73
#
# Path: //Document/TOC/TOCI[29]/Reference/Lbl
# Page: 1
# Text: 10.
#
# Path: //Document/TOC/TOCI[29]/Reference/LBody
# Page: 1
# Text: Evaluating the impact of using a particular tool ................................................................. 77
#
# Path: //Document/TOC/TOCI[30]/Span/Reference
# Page: 2
# Text: Annex 1: Sample futures and foresight material................................................................. 78
#
# Path: //Document/TOC/TOCI[31]/Span/Reference
# Page: 2
# Text: Introduction.............................................................................................................................. 78
#
# Path: //Document/TOC/TOCI[32]/Span/Reference
# Page: 2
# Text: Two horizon scanning formats ................................................................................................. 79
#
# Path: //Document/TOC/TOCI[33]/Span/Reference
# Page: 2
# Text: An example of a 7 Questions interview ................................................................................... 81
#
# Path: //Document/TOC/TOCI[34]/Span/Reference
# Page: 2
# Text: An extract from an issues paper .............................................................................................. 83
#
# Path: //Document/TOC/TOCI[35]/Span/Reference
# Page: 2
# Text: Sample drivers map ................................................................................................................. 85
#
# Path: //Document/TOC/TOCI[36]/Span/Reference
# Page: 2
# Text: Sample slides for introducing scenarios.................................................................................. 86
#
# Path: //Document/TOC/TOCI[37]/Reference/Lbl
# Page: 2
# Text: A
#
# Path: //Document/TOC/TOCI[37]/Reference/LBody
# Page: 2
# Text:  sample scenario (one from a group of four) ......................................................................... 88
#
# Path: //Document/TOC/TOCI[38]/Reference/Lbl
# Page: 2
# Text: A
#
# Path: //Document/TOC/TOCI[38]/Reference/LBody
# Page: 2
# Text:  vision..................................................................................................................................... 90
#
# Path: //Document/TOC/TOCI[39]/Span
# Page: 2
# Text: A
#
# Path: //Document/TOC/TOCI[39]/Span[2]/Reference
# Page: 2
# Text:  SWOT Analysis ..................................................................................................................... 91
#
# Path: //Document/TOC/TOCI[40]/Span/Reference
# Page: 2
# Text: Annex 2: Glossary of futures and foresight terms .............................................................. 92
#
# Path: //Document/TOC/TOCI[41]/Span/Reference
# Page: 2
# Text: Annex 3: Frequently Asked Questions ................................................................................. 94
#
# Path: //Document/TOC/TOCI[42]/Span/Reference
# Page: 2
# Text: Annex 4: Introducing metrics into scenario thinking.......................................................... 99
#
# Path: //Document/TOC/TOCI[43]/Span/Reference
# Page: 2
# Text: Annex 5: Case Studies......................................................................................................... 101
#
# Path: //Document/TOC/TOCI[44]/Span/Reference
# Page: 2
# Text: Defence Science and Technology Laboratory ....................................................................... 102
#
# Path: //Document/TOC/TOCI[45]/Span/Reference
# Page: 2
# Text: Environment Agency .............................................................................................................. 103
#
# Path: //Document/TOC/TOCI[46]/Span/Reference
# Page: 2
# Text: Forestry Commission England............................................................................................... 104
#
# Path: //Document/TOC/TOCI[47]/Span/Reference
# Page: 2
# Text: Health and Safety Executive.................................................................................................. 105
#
# Path: //Document/TOC/TOCI[48]/Span/Reference
# Page: 2
# Text: Health Education England ..................................................................................................... 106
#
# Path: //Document/TOC/TOCI[49]/Span/Reference
# Page: 2
# Text: HMRC .................................................................................................................................... 107
#
# Path: //Document/TOC/TOCI[50]/Span/Reference
# Page: 2
# Text: Natural England ..................................................................................................................... 108
#
# Path: //Document/TOC/TOCI[51]/Span/Reference
# Page: 2
# Text: Annex 6: Wider set of futures tools .................................................................................... 109
#
# Path: //Document/TOC/TOCI[52]/Span/Reference
# Page: 2
# Text: Introduction............................................................................................................................ 109
#
# Path: //Document/TOC/TOCI[53]/Span/Reference
# Page: 2
# Text: Causal Layered Analysis ........................................................................................................ 109
#
# Path: //Document/TOC/TOCI[54]/Span/Reference
# Page: 2
# Text: Dialogue ................................................................................................................................. 110
#
# Path: //Document/TOC/TOCI[55]/Span/Reference
# Page: 2
# Text: Futures Wheel ........................................................................................................................ 110
#
# Path: //Document/TOC/TOCI[56]/Span/Reference
# Page: 2
# Text: Gaming................................................................................................................................... 111
#
# Path: //Document/TOC/TOCI[57]/Span/Reference
# Page: 2
# Text: Morphological Analysis.......................................................................................................... 111
#
# Path: //Document/TOC/TOCI[58]/Span/Reference
# Page: 2
# Text: Annex 7: Further reading ..................................................................................................... 112
#
# Path: //Document/P[5]
# Page: 2
# Text: The Futures Toolkit was assembled for GO-Science by Waverley Consultants.
#
# Path: //Document/P[6]/StyleSpan/Reference
# Page: 2
# Text: futures@waverley.cloud
#
# Path: //Document/P[6]
# Page: 2
# Text: Contact
#
# Path: //Document/P[7]/StyleSpan/Reference
# Page: 2
# Text: www.waverley.cloud
#
# Path: //Document/P[7]
# Page: 2
#
# Path: //Document/H1[2]
# Page: 3
# Text: 1. Introduction
#
# Path: //Document/P[8]
# Page: 3
# Text: The Government Office for Science (GO-Science) ensures that government policies and decisions are informed by the best scientific evidence and strategic long term thinking. The Futures Toolkit is a key resource that policy professionals can use to embed long term strategic thinking in the policy and strategy process.
#
# Path: //Document/P[9]
# Page: 3
# Text: The Toolkit is designed primarily as a resource for those who are new to futures thinking but should also prove useful to more experienced practitioners. It provides an introduction to futures thinking and examines some of the important design questions that policy makers need to consider when introducing it into the policy process. The tools are organised according to their primary purpose – gathering intelligence about the future, exploring the dynamics of change, describing what the future might be like and developing and testing policy and strategy – and each procedure is set out in detail. The annexes provide examples of the outputs that different tools generate.
#
# Path: //Document/P[10]
# Page: 3
# Text: The tools are adaptable and can be customised to meet the needs of most futures projects. To illustrate this, the Toolkit sets out a number of pathways that show various ways the tools can be combined to meet specific business needs.
#
# Path: //Document/P[11]
# Page: 3
# Text: The Toolkit is practical rather than theoretical and each tool and pathway describes the design and facilitation steps required to deliver the technique. It is based on GO-Science’s1 own experience of running futures work and has been developed in collaboration with other government departments and futures practitioners who use these tools regularly in a wide range of settings.
#
# Path: //Document/P[12]
# Page: 3
# Text: There are ten chapters:
#
# Path: //Document/L/LI/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI/LBody
# Page: 3
# Text: Chapter 1 introduces the Toolkit
#
# Path: //Document/L/LI[2]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[2]/LBody
# Page: 3
# Text: Chapter 2 provides an introduction to futures thinking
#
# Path: //Document/L/LI[3]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[3]/LBody
# Page: 3
# Text: Chapter 3 sets out key principles that underpin futures process design
#
# Path: //Document/L/LI[4]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[4]/LBody
# Page: 3
# Text: Chapter 4 provides a guide to using the Toolkit
#
# Path: //Document/L/LI[5]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[5]/LBody
# Page: 3
# Text: Chapter 5 describes 7 pathways that combine tools to meet specific business needs
#
# Path: //Document/L/LI[6]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[6]/LBody/ParagraphSpan
# Page: 3
# Text: Chapters 6 to 9 set out the full suite of tools:
#
# Path: //Document/L/LI[6]/LBody/L/LI/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[6]/LBody/L/LI/LBody
# Page: 3
# Text: Chapter 6 describes tools for gathering intelligence about the future
#
# Path: //Document/L/LI[6]/LBody/L/LI[2]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[6]/LBody/L/LI[2]/LBody
# Page: 3
# Text: Chapter 7 describes tools for exploring the dynamics of change
#
# Path: //Document/L/LI[6]/LBody/L/LI[3]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[6]/LBody/L/LI[3]/LBody
# Page: 3
# Text: Chapter 8 describes tools for describing what the future might be like
#
# Path: //Document/L/LI[6]/LBody/L/LI[4]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[6]/LBody/L/LI[4]/LBody
# Page: 3
# Text: Chapter 9 describes tools for developing and testing policy and strategy
#
# Path: //Document/L/LI[7]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L/LI[7]/LBody
# Page: 3
# Text: Chapter 10 provides guidance on evaluating the impact of using the tools
#
# Path: //Document/P[13]
# Page: 3
# Text: There are seven annexes:
#
# Path: //Document/L[2]/LI/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI/LBody
# Page: 3
# Text: Annex 1: Sample futures and foresight material
#
# Path: //Document/L[2]/LI[2]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI[2]/LBody
# Page: 3
# Text: Annex 2: Glossary of futures and foresight terms
#
# Path: //Document/L[2]/LI[3]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI[3]/LBody
# Page: 3
# Text: Annex 3: Frequently Asked Questions
#
# Path: //Document/L[2]/LI[4]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI[4]/LBody
# Page: 3
# Text: Annex 4: Introducing metrics into scenario thinking
#
# Path: //Document/L[2]/LI[5]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI[5]/LBody
# Page: 3
# Text: Annex 5: Case studies
#
# Path: //Document/L[2]/LI[6]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI[6]/LBody
# Page: 3
# Text: Annex 6: Wider set of futures tools
#
# Path: //Document/L[2]/LI[7]/Lbl
# Page: 3
# Text: •
#
# Path: //Document/L[2]/LI[7]/LBody
# Page: 3
# Text: Annex 7: References and further resources
#
# Path: //Document/Footnote
# Page: 3
# Text: 1 GO-Science conducts its Horizon Scanning activities in conjunction with the Cabinet Office through the jointly run Horizon Scanning Programme Team initiative.
#
# Path: //Document/H1[3]
# Page: 4
# Text: 2. Introduction to futures thinking
#
# Path: //Document/H2
# Page: 4
# Text: Thinking about the future
#
# Path: //Document/P[14]
# Page: 4
# Text: ‘Futures’ is an approach to identifying the long term issues and challenges shaping the future development of a policy area and to exploring their implications for policy development. It provides a set of research and modelling tools that policy makers can use to support development of policy that is resilient to a range of possible outcomes.
#
# Path: //Document/P[15]
# Page: 4
# Text: Futures is a flexible approach that can be adapted as required. A new team starting out in a new policy area may find that scenarios are a useful way to structure discussion at an away day to explore the emerging policy context and priorities. They may use the day to brainstorm change drivers, build scenarios and discuss the opportunities and threats each scenario poses. They may decide that the scenario process is a good way to structure the conversation but that there is no need to write up the stories themselves.
#
# Path: //Document/P[16]
# Page: 4
# Text: Alternatively, the team might decide that they want a detailed set of scenarios to test new policy ideas and that they need an extended process to develop them. They may want to research drivers in detail, to run separate drivers workshops and scenario workshops and to invite a range of external participants to take part in the process. They may want to publish – or at least circulate widely – the scenario narratives to promote discussion amongst an extended stakeholder group. Before they do so, they will want to write detailed scenarios that pick up all the key issues raised during the workshop process.
#
# Path: //Document/P[17]
# Page: 4
# Text: Although the aims of each exercise are different the same techniques are used in both, adapted to meet the particular requirements of each situation. The purpose of the first exercise is to provide a sandbox for the new team to explore issues and the potential shape of the future they are developing policy for. The scenarios themselves are less important than the conversation. The purpose of the second is to use future thinking to engage stakeholders and to develop a reasoned, robust perspective on possible future developments in the policy area. The output is designed to raise awareness of the issues shaping the future and, perhaps, stimulate debate about what is a desirable policy outcome.
#
# Path: //Document/P[18]
# Page: 4
# Text: Flexibility makes futures a powerful process that can be applied in a range of ways to help policy makers:
#
# Path: //Document/L[3]/LI/Lbl
# Page: 4
# Text: •
#
# Path: //Document/L[3]/LI/LBody
# Page: 4
# Text: deepen their understanding of the driving forces affecting future development of the policy or strategy area
#
# Path: //Document/L[3]/LI[2]/Lbl
# Page: 4
# Text: •
#
# Path: //Document/L[3]/LI[2]/LBody
# Page: 4
# Text: identify gaps in their knowledge and suggest areas of new research required to understand driving forces better
#
# Path: //Document/L[3]/LI[3]/Lbl
# Page: 4
# Text: •
#
# Path: //Document/L[3]/LI[3]/LBody
# Page: 4
# Text: build consensus amongst a range of stakeholders about the issues and how to tackle them
#
# Path: //Document/L[3]/LI[4]/Lbl
# Page: 4
# Text: •
#
# Path: //Document/L[3]/LI[4]/LBody
# Page: 4
# Text: identify and make explicit some of the difficult policy choices and trade offs in the future
#
# Path: //Document/L[3]/LI[5]/Lbl
# Page: 4
# Text: •
#
# Path: //Document/L[3]/LI[5]/LBody
# Page: 4
# Text: create a new strategy that is resilient because it is adaptable to changing external conditions
#
# Path: //Document/L[3]/LI[6]/Lbl
# Page: 4
# Text: •
#
# Path: //Document/L[3]/LI[6]/LBody
# Page: 4
# Text: mobilise stakeholders to action
#
# Path: //Document/P[19]
# Page: 4
# Text: Flexibility does, however, mean there is no ‘standard’ approach to futures that less experienced project owners can simply take off the shelf and deliver. Every project needs to be designed to meet its own particular requirements. This chapter and Chapter 2 set out some of the underpinning principles of futures thinking in detail as an aid to the design process.
#
# Path: //Document/H2[2]
# Page: 5
# Text: Looking ahead
#
# Path: //Document/P[20]
# Page: 5
# Text: Horizon Scanning is a technique for looking ahead. Its focus is the future rather than the present and its purpose is to identify the strategic issues that will be important. Mostly, these will be different from the issues that are important today.
#
# Path: //Document/P[21]
# Page: 5
# Text: The Three Horizons model (Figure 1) illustrates how strategic issues change over time.
#
# Path: //Document/P[22]
# Page: 5
# Text: The present and the near future is defined in the model as Horizon 1 (H1). H1 issues are strategically important now. They are visible and well understood and are generally the issues that government and its stakeholders are already responding to. H1 issues are therefore the focus of current policy and strategy.
#
# Path: //Document/Figure[4]
# Page: 5
#
# Path: //Document/Figure[4]
# Page: 5
# Text: Strategic Importance H M L Now Short term Long termMedium term Horizon 1 Horizon 2 Horizon 3
#
# Path: //Document/P[23]
# Page: 5
# Text: Figure 1: The three horizons model
#
# Path: //Document/P[24]
# Page: 5
# Text: H1 issues will become less important over time. They may be assimilated into policy or strategy or they may be overtaken by other trends or events that are less important now but will become more important in the medium term – Horizon 2 (H2). Exactly how H2 will develop may not be apparent yet, but many of the key trends and factors – the change drivers – that will define it are already in play. The task for regulators, policy makers and strategists is to look at these issues closely, to explore the possible outcomes and to adapt policy and strategy in anticipation of future need. Ideally, this should be a collaborative process.
#
# Path: //Document/P[25]
# Page: 5
# Text: In the long term, H2 will give way to Horizon 3 (H3) and a new set of policy and strategy challenges will emerge. These, too, will require a response from policy makers, but the change drivers that will shape H3 are difficult to see in the present. It is not clear how H3 factors will develop, how they will interact or whether they will create opportunities or threats for stakeholders in the future. The task for regulators, policy makers and strategists here is therefore to identify and track the drivers that will shape H3. Doing so allows them to develop foresight about the strategic challenges and choices they might face in the long term future and to explore what kind of policy or strategy might be required to sustain success.
#
# Path: //Document/P[26]
# Page: 5
# Text: The main focus for futures and foresight is therefore the mid to long term: Horizon 2 and Horizon 3. The tools and techniques are designed to help policy makers identify the change drivers, to explore the various ways they might combine to change the future policy environment and to consider what the best policy response might be.
#
# Path: //Document/P[27]
# Page: 5
# Text: There is no fixed definition of what ‘mid to long term’ means. Timeframe is defined on a project by project basis, drawing on relevant factors (such as, for example, technology development, market development, consumer uptake and systemic change). For some projects this can mean thinking about a relatively near future – 15 to 20 years, say – and for others it might mean 50 to 60 years.
#
# Path: //Document/H2[3]
# Page: 6
# Text: What to look for
#
# Path: //Document/P[28]
# Page: 6
# Text: Identifying and mapping change drivers – the key trends and factors shaping the long term development of the policy area – sits at the core of most futures and foresight work. Change drivers are typically characterised as the political, economic, societal, technological, legislative or environmental factors (shortened to the acronym PESTLE).
#
# Path: //Document/P[29]
# Page: 6
# Text: It is important to look beyond the current policy environment when identifying change drivers (Figure 2). Many of the drivers that will shape development of Horizon 2 and Horizon 3 will emerge from outside the policy area and it is important to think broadly and capture a wide range of drivers. It is always better to identify too many drivers – irrelevant one can be discarded later – than to think too narrowly and miss what could be important for the future.
#
# Path: //Document/Figure[5]
# Page: 6
#
# Path: //Document/Figure[5]
# Page: 6
# Text: Wider (global) context Drivers EconoSociet Techn LegislEnviroPolicy delivery space Policy  development space Political mic al ological ative nmental Drivers
#
# Path: //Document/P[30]
# Page: 6
# Text: Figure 2: Where to look for change drivers
#
# Path: //Document/H2[4]
# Page: 6
# Text: Identifying weak signals
#
# Path: //Document/P[31]
# Page: 6
# Text: It is often easy to understand what is happening in and around a policy area in the present and near future. Important H1 trends and events stand out against the background and their impacts are clearly signalled to policy makers. The further forward scanners look, however, the weaker these signals become and the harder it can be to spot patterns and make sense of their meaning (Figure 3).
#
# Path: //Document/Figure[6]
# Page: 6
#
# Path: //Document/Figure[6]
# Page: 6
# Text: H1 H2 H3
#
# Path: //Document/P[32]
# Page: 6
# Text: Figure 3: Intensity of signal
#
# Path: //Document/P[33]
# Page: 6
# Text: Horizon Scanning (a tool, see Chapter 6) focuses on identifying and making sense of these weak signals. By definition, there is little or no robust evidence associated with them and scanners may find it hard initially to identify exactly what the impact is going to be.
#
# Path: //Document/P[34]
# Page: 6
# Text: They may find it equally hard to explain why they believe a weak signal is important. That needn’t matter. In the absence of robust evidence, scanners should trust their intuition when it tells them a weak signal indicates something that will be strategically important in the future.
#
# Path: //Document/H2[5]
# Page: 6
# Text: Linking futures and foresight to the policy and strategy cycle
#
# Path: //Document/P[35]
# Page: 6
# Text: In its simplest form, a policy cycle can be described as having 5 steps (Figure 4):
#
# Path: //Document/L[4]/LI/Lbl
# Page: 6
# Text: •
#
# Path: //Document/L[4]/LI/LBody
# Page: 6
# Text: Formulate policy using consultation, research and fit with the wider strategic or policy aims of government to establish relevant goals and targets
#
# Path: //Document/L[4]/LI[2]/Lbl
# Page: 6
# Text: •
#
# Path: //Document/L[4]/LI[2]/LBody
# Page: 6
# Text: Implement policy by creating and funding appropriate initiatives and policy instruments
#
# Path: //Document/L[4]/LI[3]/Lbl
# Page: 6
# Text: •
#
# Path: //Document/L[4]/LI[3]/LBody/ParagraphSpan
# Page: 6
# Text: Monitor events to track progress towards goals and targets and to adjust activity if necessary
#
# Path: //Document/L[4]/LI[3]/LBody/Figure
# Page: 6
#
# Path: //Document/L[4]/LI[3]/LBody/P
# Page: 6
# Text: Figure 4: Illustrative policy cycle
#
# Path: //Document/L[4]/LI[4]/Lbl
# Page: 7
# Text: •
#
# Path: //Document/L[4]/LI[4]/LBody
# Page: 7
# Text: Evaluate impact against the project goals and targets and to test contribution to the overall strategy
#
# Path: //Document/L[4]/LI[5]/Lbl
# Page: 7
# Text: •
#
# Path: //Document/L[4]/LI[5]/LBody
# Page: 7
# Text: Modify the objectives if required to increase impact or strategic relevance
#
# Path: //Document/P[36]
# Page: 7
# Text: Looked at strategically, futures and foresight can be divided into four stages:
#
# Path: //Document/L[5]/LI/Lbl
# Page: 7
# Text: •
#
# Path: //Document/L[5]/LI/LBody
# Page: 7
# Text: Gathering intelligence about the future
#
# Path: //Document/L[5]/LI[2]/Lbl
# Page: 7
# Text: •
#
# Path: //Document/L[5]/LI[2]/LBody
# Page: 7
# Text: Exploring the dynamics of change
#
# Path: //Document/L[5]/LI[3]/Lbl
# Page: 7
# Text: •
#
# Path: //Document/L[5]/LI[3]/LBody
# Page: 7
# Text: Describing what the future might be like
#
# Path: //Document/L[5]/LI[4]/Lbl
# Page: 7
# Text: •
#
# Path: //Document/L[5]/LI[4]/LBody
# Page: 7
# Text: Developing and testing policy and strategy responses
#
# Path: //Document/P[37]
# Page: 7
# Text: Futures and foresight’s primary input to the policy cycle is at the ‘Formulate policy’ step (Figure 5). This is where the ideas and insights that emerge from futures work can make their greatest contribution to policy development.
#
# Path: //Document/P[38]
# Page: 7
# Text: The connection between futures and foresight, and policy cannot, however, be taken for granted and many organisations find it culturally or procedurally difficult to make the link. Where this happens, futures can have less impact than it might otherwise do. Project owners therefore need to be alert to the possibility that their work may not have a guaranteed connection to wider policy and strategy discussions and need to factor that into the project design.
#
# Path: //Document/Figure[7]
# Page: 7
#
# Path: //Document/P[39]
# Page: 7
# Text: Figure 5: The futures bridge
#
# Path: //Document/P[40]
# Page: 7
# Text: One way to strengthen the connection is to involve as wide a group of policy makers as possible. Not only will this raise awareness of the project, but gathering intelligence from key stakeholders will build a bridge to current policy and strategy activity (Figure 5). If stakeholders have limited time, for example, they can be invited to contribute one or more scans or to participate in a 7 Questions interview (Chapter 6). If they have more time – or if it is important to engage them more deeply in the futures process – they can be invited to take part in a pathways workshop (Chapter 5) or a more extended project.
#
# Path: //Document/H1[4]
# Page: 8
# Text: 3. Futures process design
#
# Path: //Document/H2[6]
# Page: 8
# Text: Introduction
#
# Path: //Document/P[41]
# Page: 8
# Text: Every futures project is different. Some are large scale, involving extensive consultation, detailed research and stakeholder workshops to identify and advise on future policy challenges. Others are small scale, perhaps requiring only a single workshop with an internal policy or strategy team to explore what’s driving change in the future and what that means for their own plan.
#
# Path: //Document/P[42]
# Page: 8
# Text: This chapter therefore sets out some of the common design issues that practitioners may encounter at the start of a new futures project and offers guidance on how to address them.
#
# Path: //Document/H2[7]
# Page: 8
# Text: The project aims
#
# Path: //Document/P[43]
# Page: 8
# Text: Defining the specific aims of a futures project is not necessarily a trivial exercise and can take several rounds of discussion.
#
# Path: //Document/P[44]
# Page: 8
# Text: The Intelligent Infrastructure Futures project, conducted by GO-Science’s Foresight unit, for example, was set up to…explore how future science and technology may be applied over the next 50 years to deliver robust, sustainable, intelligent, responsive and adaptive infrastructure systems.
#
# Path: //Document/P[45]
# Page: 8
# Text: GO-Science’s Foresight project on Future of Food and Farming aimed to…explore the pressures on the global food system between now and 2050 and identify the decisions that policy makers need to take today, and in the years ahead, to ensure that a global population rising to nine billion or more can be fed sustainably and equitably.
#
# Path: //Document/P[46]
# Page: 8
# Text: These aims are quite distinct. Intelligent Infrastructure set out to explore how emerging science and technology might be applied to deliver a desired outcome. Food and Farming focused on policy decision making to deliver a desired outcome. Both projects considered science and technology, politics and decision making, value and values and the relationship between the future and the present but they approached it in different ways that were informed by the different aims.
#
# Path: //Document/P[47]
# Page: 8
# Text: Once a project aim is agreed, it can be used to shape process design. Project leaders should not, however, be concerned if they decide to adjust the aims in light of early discussions with stakeholders and others.
#
# Path: //Document/P[48]
# Page: 8
# Text: Project aims are sometimes captured as a question (‘How might future science and technology be applied over the next 50 years to deliver robust, sustainable, intelligent, responsive and adaptive infrastructure systems?’). The question should be framed in broad terms rather than specific ones and should be open and not too focused. A question such as ‘How will the design of cities in 50 years’ time create social and economic wellbeing?’ is likely to lead to a richer conversation than ‘How should we design the city of the future?’ A broad question helps participants think more widely about the range of factors that (in this case) define the purpose and development of a city and its population rather than focusing solely on physical structure.
#
# Path: //Document/H2[8]
# Page: 8
# Text: Scale
#
# Path: //Document/P[49]
# Page: 8
# Text: Futures projects can be large or small. They may be delivered primarily in house or they may involve a wide range of external stakeholders. Participants may be familiar with futures and foresight or they may have little knowledge of it.
#
# Path: //Document/P[50]
# Page: 8
# Text: Intelligent Infrastructure Futures, for example, engaged nearly 300 people at national, regional and local level and commissioned leading researchers to write 18 state of the art research reviews covering areas as diverse as artificial intelligence, data mining, how information affects our choices and the psychology of travel.
#
# Path: //Document/P[51]
# Page: 9
# Text: At the other end of the scale, the Health and Safety Executive uses futures and foresight to identify new and emerging issues that might affect future workplace health and safety2. Five FTEs use a range of tools – Horizon Scanning, 7 Questions, Delphi, Driver Mapping, Axes of Uncertainty, Scenarios, Policy Stress-testing and SWOT Analysis – on a continuing basis to inform specialists and policy colleagues of what the future implications of emerging issues might be.
#
# Path: //Document/P[52]
# Page: 9
# Text: There is no optimal scale for futures and foresight processes, but processes require some adjustment and project planning if they are to be scaled up – or down – significantly.
#
# Path: //Document/H2[9]
# Page: 9
# Text: Who to involve
#
# Path: //Document/P[53]
# Page: 9
# Text: Anyone with any kind of interest in – or influence on – the future of the policy or strategy issue can be invited to participate in a futures project. In particular, anyone who is likely to use the project outputs should be involved in their development if possible. If a strategy team is developing scenarios for an executive board, for example, the executive board should be involved in developing the scenarios and not just be given them at the end of a process. This will ensure the knowledge and insights of the executive board are included in the scenarios. It will also ensure the executive have ownership of the scenarios.
#
# Path: //Document/P[54]
# Page: 9
# Text: It is important to involve key stakeholders and senior decisions makers early in the process in order to build ownership and understanding of the futures approach and its outputs. Invite them to participate in development workshops or contribute to horizon scans. Experts or senior figures who have limited time and can’t make the workshop programme should at least be interviewed. International experts should be involved in Delphi to gather their opinion on strategic issues.
#
# Path: //Document/P[55]
# Page: 9
# Text: Aim to involve as wide a group of stakeholders as possible such as other departments, businesses, third sector organisations and interest groups. A particular benefit of the futures approach is that stakeholders with differing, even conflicting, objectives can work together to develop and explore future scenarios. Bringing individuals with different opinions into Horizon Scanning, interview programmes and scenario workshops facilitates development and sharing of new insights and effective responses to future challenges.
#
# Path: //Document/Footnote[2]
# Page: 9
# Text: 2 There is more detail on this project – and others across government – in Annex 4.
#
# Path: //Document/H1[5]
# Page: 10
# Text: 4. Using the toolkit
#
# Path: //Document/H2[10]
# Page: 10
# Text: Introduction
#
# Path: //Document/P[56]
# Page: 10
# Text: The Toolkit contains 12 tools, organized into four categories and described in detail in the relevant chapter.
#
# Path: //Document/P[57]
# Page: 10
# Text: There are four tools for gathering intelligence about the future ➲ Chapter 6
#
# Path: //Document/L[6]/LI/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[6]/LI/LBody
# Page: 10
# Text: Horizon Scanning
#
# Path: //Document/L[6]/LI[2]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[6]/LI[2]/LBody
# Page: 10
# Text: 7 Questions
#
# Path: //Document/L[6]/LI[3]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[6]/LI[3]/LBody
# Page: 10
# Text: The Issues Paper
#
# Path: //Document/L[6]/LI[4]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[6]/LI[4]/LBody
# Page: 10
# Text: Delphi
#
# Path: //Document/Table
# Page: 10
# File paths: ['tables/fileoutpart0.csv']
#
# Path: //Document/Table/TR/TD
# Page: 10
#
# Path: //Document/Table/TR/TD/P
# Page: 10
# Text: There are two tools for exploring the dynamics of change
#
# Path: //Document/Table/TR/TD/L/LI/Lbl
# Page: 10
# Text: •
#
# Path: //Document/Table/TR/TD/L/LI/LBody
# Page: 10
# Text: Driver Mapping
#
# Path: //Document/Table/TR/TD/L/LI[2]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/Table/TR/TD/L/LI[2]/LBody
# Page: 10
# Text: Axes of Uncertainty
#
# Path: //Document/Table/TR/TD[2]
# Page: 10
#
# Path: //Document/Table/TR/TD[2]/P
# Page: 10
# Text: ➲  Chapter 7
#
# Path: //Document/P[58]
# Page: 10
# Text: There are three tools for describing what the future might be like
#
# Path: //Document/L[7]/LI/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[7]/LI/LBody
# Page: 10
# Text: Scenarios
#
# Path: //Document/L[7]/LI[2]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[7]/LI[2]/LBody
# Page: 10
# Text: Visioning
#
# Path: //Document/L[7]/LI[3]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[7]/LI[3]/LBody
# Page: 10
# Text: SWOT Analysis
#
# Path: //Document/P[59]
# Page: 10
# Text: There are three tools for developing and testing policy and strategy
#
# Path: //Document/L[8]/LI/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[8]/LI/LBody
# Page: 10
# Text: Policy Stress-testing
#
# Path: //Document/L[8]/LI[2]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[8]/LI[2]/LBody
# Page: 10
# Text: Backcasting
#
# Path: //Document/L[8]/LI[3]/Lbl
# Page: 10
# Text: •
#
# Path: //Document/L[8]/LI[3]/LBody/ParagraphSpan
# Page: 10
# Text: Roadmapping
#
# Path: //Document/L[8]/LI[3]/LBody/L/LI/Lbl
# Page: 10
# Text: ➲
#
# Path: //Document/L[8]/LI[3]/LBody/L/LI/LBody
# Page: 10
# Text:  Chapter 8
#
# Path: //Document/L[8]/LI[3]/LBody/L/LI[2]/Lbl
# Page: 10
# Text: ➲
#
# Path: //Document/L[8]/LI[3]/LBody/L/LI[2]/LBody
# Page: 10
# Text:  Chapter 9
#
# Path: //Document/P[60]
# Page: 10
# Text: The tools are summarised in the tables on pages 9 to 12. The relationship between the different categories is presented graphically in the icon map on page 13.
#
# Path: //Document/P[61]
# Page: 10
# Text: The Toolkit also contains 7 pathways – tools combined in particular ways to meet specific business needs. The pathways are set out in Chapter 5.
#
# Path: //Document/P[62]
# Page: 10
# Text: The final two sections of this chapter introduce the guidance notes for facilitators and the navigation flags.
#
# Path: //Document/H2[11]
# Page: 11
# Text: Tools for gathering intelligence about the future
#
# Path: //Document/Table[2]
# Page: 11
# File paths: ['tables/fileoutpart1.csv']
#
# Path: //Document/Table[2]/TR/TH
# Page: 11
#
# Path: //Document/Table[2]/TR/TH/P
# Page: 11
# Text: Tool
#
# Path: //Document/Table[2]/TR/TH[2]
# Page: 11
#
# Path: //Document/Table[2]/TR/TH[2]/P
# Page: 11
# Text: Use it to
#
# Path: //Document/Table[2]/TR/TH[3]
# Page: 11
#
# Path: //Document/Table[2]/TR/TH[3]/P
# Page: 11
# Text: Time required
#
# Path: //Document/Table[2]/TR[2]/TD
# Page: 11
#
# Path: //Document/Table[2]/TR[2]/TD/P/Figure
# Page: 11
#
# Path: //Document/Table[2]/TR[2]/TD/P
# Page: 11
# Text: Horizon Scanning
#
# Path: //Document/Table[2]/TR[2]/TD/P[2]/Sub
# Page: 11
# Text: is the process of
#
# Path: //Document/Table[2]/TR[2]/TD/P[2]/Sub[2]
# Page: 11
# Text: looking for early
#
# Path: //Document/Table[2]/TR[2]/TD/P[2]/Sub[3]
# Page: 11
# Text: warning signs
#
# Path: //Document/Table[2]/TR[2]/TD/P[2]/Sub[4]
# Page: 11
# Text: of change in the
#
# Path: //Document/Table[2]/TR[2]/TD/P[2]/Sub[5]
# Page: 11
# Text: policy and strategy
#
# Path: //Document/Table[2]/TR[2]/TD/P[2]/Sub[6]
# Page: 11
# Text: environment
#
# Path: //Document/Table[2]/TR[2]/TD[2]
# Page: 11
#
# Path: //Document/Table[2]/TR[2]/TD[2]/L/LI/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[2]/TD[2]/L/LI/LBody
# Page: 11
# Text: involve a wide group of people in futures thinking
#
# Path: //Document/Table[2]/TR[2]/TD[2]/L/LI[2]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[2]/TD[2]/L/LI[2]/LBody
# Page: 11
# Text: gather a data bank of ideas about trends and events shaping the future
#
# Path: //Document/Table[2]/TR[2]/TD[3]
# Page: 11
#
# Path: //Document/Table[2]/TR[2]/TD[3]/L/LI/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[2]/TD[3]/L/LI/LBody
# Page: 11
# Text: run it over a number of weeks as a one off exercise
#
# Path: //Document/Table[2]/TR[2]/TD[3]/L/LI[2]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[2]/TD[3]/L/LI[2]/LBody
# Page: 11
# Text: run it throughout a project to build strategic intelligence about change in the external environment
#
# Path: //Document/Table[2]/TR[3]/TD
# Page: 11
#
# Path: //Document/Table[2]/TR[3]/TD/P/Figure
# Page: 11
#
# Path: //Document/Table[2]/TR[3]/TD/P
# Page: 11
# Text: 7 Questions is an interview technique for gathering the strategic insights of a range of internal and external stakeholders
#
# Path: //Document/Table[2]/TR[3]/TD[2]
# Page: 11
#
# Path: //Document/Table[2]/TR[3]/TD[2]/L/LI/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[3]/TD[2]/L/LI/LBody
# Page: 11
# Text: identify conflicting or challenging views of the future
#
# Path: //Document/Table[2]/TR[3]/TD[2]/L/LI[2]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[3]/TD[2]/L/LI[2]/LBody
# Page: 11
# Text: extract deep information about underlying concerns in a policy area
#
# Path: //Document/Table[2]/TR[3]/TD[2]/L/LI[3]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[3]/TD[2]/L/LI[3]/LBody
# Page: 11
# Text: stimulate individuals’ thinking in preparation for a futures workshop
#
# Path: //Document/Table[2]/TR[3]/TD[3]
# Page: 11
#
# Path: //Document/Table[2]/TR[3]/TD[3]/L/LI/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[3]/TD[3]/L/LI/LBody
# Page: 11
# Text: 60 minutes to conduct each interview
#
# Path: //Document/Table[2]/TR[3]/TD[3]/L/LI[2]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[3]/TD[3]/L/LI[2]/LBody
# Page: 11
# Text: 60 minutes to write up each interview
#
# Path: //Document/Table[2]/TR[4]/TD
# Page: 11
#
# Path: //Document/Table[2]/TR[4]/TD/P/Figure
# Page: 11
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub
# Page: 11
# Text: The Issues
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[2]
# Page: 11
# Text: Paper presents
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[3]
# Page: 11
# Text: quotes from
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[4]
# Page: 11
# Text: the 7 Questions
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[5]
# Page: 11
# Text: interviews to
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[6]
# Page: 11
# Text: illustrate the
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[7]
# Page: 11
# Text: strategic issues and
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[8]
# Page: 11
# Text: choices around the
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[9]
# Page: 11
# Text: policy and strategy
#
# Path: //Document/Table[2]/TR[4]/TD/P/Sub[10]
# Page: 11
# Text: agenda
#
# Path: //Document/Table[2]/TR[4]/TD[2]
# Page: 11
#
# Path: //Document/Table[2]/TR[4]/TD[2]/P
# Page: 11
# Text: • capture different perspectives from the 7 Questions interviews about what success in the future will be like and what needs to be done to achieve it
#
# Path: //Document/Table[2]/TR[4]/TD[3]
# Page: 11
#
# Path: //Document/Table[2]/TR[4]/TD[3]/P
# Page: 11
# Text: • allow 20 to 30 minutes to process each of the 7 Questions interview per interview
#
# Path: //Document/Table[2]/TR[5]/TD
# Page: 11
#
# Path: //Document/Table[2]/TR[5]/TD/P/Figure
# Page: 11
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub
# Page: 11
# Text: Delphi is a
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[2]
# Page: 11
# Text: consultation
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[3]
# Page: 11
# Text: process used to
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[4]
# Page: 11
# Text: gather opinion
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[5]
# Page: 11
# Text: from a wide group
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[6]
# Page: 11
# Text: of subject experts
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[7]
# Page: 11
# Text: about the future
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[8]
# Page: 11
# Text: and to prioritise the
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[9]
# Page: 11
# Text: issues of strategic
#
# Path: //Document/Table[2]/TR[5]/TD/P/Sub[10]
# Page: 11
# Text: importance
#
# Path: //Document/Table[2]/TR[5]/TD[2]
# Page: 11
#
# Path: //Document/Table[2]/TR[5]/TD[2]/L/LI/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[5]/TD[2]/L/LI/LBody
# Page: 11
# Text: gather opinion from a group of experts
#
# Path: //Document/Table[2]/TR[5]/TD[2]/L/LI[2]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[5]/TD[2]/L/LI[2]/LBody
# Page: 11
# Text: refine thinking on the future
#
# Path: //Document/Table[2]/TR[5]/TD[2]/L/LI[3]/Lbl
# Page: 11
# Text: •
#
# Path: //Document/Table[2]/TR[5]/TD[2]/L/LI[3]/LBody
# Page: 11
# Text: highlight the potential trade offs and choices that policy design will need to address
#
# Path: //Document/Table[2]/TR[5]/TD[3]
# Page: 11
#
# Path: //Document/Table[2]/TR[5]/TD[3]/P
# Page: 11
# Text: • varies. Can take several weeks
#
# Path: //Document/H2[12]
# Page: 12
# Text: Tools for exploring the dynamics of change
#
# Path: //Document/Table[3]
# Page: 12
# File paths: ['tables/fileoutpart2.csv']
#
# Path: //Document/Table[3]/TR/TH
# Page: 12
#
# Path: //Document/Table[3]/TR/TH/P
# Page: 12
# Text: Tool overview
#
# Path: //Document/Table[3]/TR/TH[2]
# Page: 12
#
# Path: //Document/Table[3]/TR/TH[2]/P
# Page: 12
# Text: Use it to
#
# Path: //Document/Table[3]/TR/TH[3]
# Page: 12
#
# Path: //Document/Table[3]/TR/TH[3]/P
# Page: 12
# Text: Time required
#
# Path: //Document/Table[3]/TR[2]/TD
# Page: 12
#
# Path: //Document/Table[3]/TR[2]/TD/P/Figure
# Page: 12
#
# Path: //Document/Table[3]/TR[2]/TD/P
# Page: 12
# Text: Driver mapping
#
# Path: //Document/Table[3]/TR[2]/TD/P[2]/Sub
# Page: 12
# Text: is used to identify
#
# Path: //Document/Table[3]/TR[2]/TD/P[2]/Sub[2]
# Page: 12
# Text: the political,
#
# ...
# Page: 111
# Text: •
#
# Path: //Document/L[71]/LI[3]/LBody
# Page: 111
# Text: Futures Wheel
#
# Path: //Document/L[71]/LI[4]/Lbl
# Page: 111
# Text: •
#
# Path: //Document/L[71]/LI[4]/LBody
# Page: 111
# Text: Gaming
#
# Path: //Document/L[71]/LI[5]/Lbl
# Page: 111
# Text: •
#
# Path: //Document/L[71]/LI[5]/LBody
# Page: 111
# Text: Morphological Analysis
#
# Path: //Document/H2[98]
# Page: 111
# Text: Causal Layered Analysis
#
# Path: //Document/P[378]
# Page: 111
# Text: Causal Layered Analysis is particularly useful for exploring deep structure in a policy areas and for identifying how to co-ordinate policy responses to achieve the desired outcome.
#
# Path: //Document/P[379]
# Page: 111
# Text: Causal Layered Analysis (CLA) identifies the driving forces and worldviews underpinning diverse perspectives about the future and what it means to different groups through discussion and deconstruction of conventional thinking. Based on that, CLA is able to produce a shared view of possible future outcomes that can break existing paradigms of thinking and operating. It is particularly useful when different groups hold different perspectives on the future of the policy area.
#
# Path: //Document/P[380]
# Page: 111
# Text: CLA explores issues at four levels – Litany, Social Causes, World View and Metaphor. This layered approach increases meaning and results in a wider realm of possible change for the participants. The technique combines the nature of past, present and future in its investigation.
#
# Path: //Document/P[381]
# Page: 111
# Text: After defining the issue to be explored, conduct brainstorms on it at each of the four CLA levels, in sequence. Capture the brainstorms on Post-it notes and allow time for discussion. Cluster these into themes where appropriate.
#
# Path: //Document/P[382]
# Page: 111
# Text: Once complete, begin a new scenario by selecting/creating an alternative myth. Then, work in reverse order, upwards, through the layers to create the scenario with more brainstorming. In this way, the myth, world view and causes build a litany and set of ‘events’ to fulfil the scenario.
#
# Path: //Document/P[383]
# Page: 111
# Text: In summary:
#
# Path: //Document/L[72]/LI/Lbl
# Page: 111
# Text: 1.
#
# Path: //Document/L[72]/LI/LBody
# Page: 111
# Text: Layer 1: Analyse the litany of current events, trends and conditions.
#
# Path: //Document/L[72]/LI[2]/Lbl
# Page: 111
# Text: 2.
#
# Path: //Document/L[72]/LI[2]/LBody
# Page: 111
# Text: Layer 2: Analyse the causes, such as STEEP factors, the intent of government, relationships and systems.
#
# Path: //Document/L[72]/LI[3]/Lbl
# Page: 111
# Text: 3.
#
# Path: //Document/L[72]/LI[3]/LBody
# Page: 111
# Text: Layer 3: Explore the world view. These will be deeper matters of discourse, values and cultural structures.
#
# Path: //Document/L[72]/LI[4]/Lbl
# Page: 111
# Text: 4.
#
# Path: //Document/L[72]/LI[4]/LBody
# Page: 111
# Text: Layer 4: Explore metaphor, or myths. These are emotive, less-specific, heart-felt issues and archetypes.
#
# Path: //Document/P[384]/StyleSpan/Reference
# Page: 111
# Text: The Causal Layered Analysis Reader
#
# Path: //Document/P[384]
# Page: 111
# Text: See  (2004)
#
# Path: //Document/H2[99]
# Page: 112
# Text: Dialogue
#
# Path: //Document/P[385]
# Page: 112
# Text: Dialogue is an open space technique where participants work together to explore whatever aspects of the futures issue are important to them. It is particularly useful for exploring what stakeholders believe to be the priority issues for the policy area.
#
# Path: //Document/P[386]
# Page: 112
# Text: Dialogue is an inquisitive review of a topic. It is, practically speaking, an intelligent exchange of ideas. To encourage personal insights, dialogue should incorporate open-ended questions, observations, good listening skills and a focus on contextual information. One key output of dialogue is the establishment of topic structures and areas for further investigation. Dialogue is a stand-alone futures tool. It is also one solid way to ‘join up’ a number of futures activities taking place and a powerful way to encourage engagement with a futures project team.
#
# Path: //Document/P[387]
# Page: 112
# Text: There are 6 steps:
#
# Path: //Document/L[73]/LI/Lbl
# Page: 112
# Text: 1.
#
# Path: //Document/L[73]/LI/LBody
# Page: 112
# Text: State the topic to be discussed and allow time for the participants to explore it as individuals.
#
# Path: //Document/L[73]/LI[2]/Lbl
# Page: 112
# Text: 2.
#
# Path: //Document/L[73]/LI[2]/LBody
# Page: 112
# Text: Ask one participant, or an external, to prepare and to briefly present one aspect of the topic.
#
# Path: //Document/L[73]/LI[3]/Lbl
# Page: 112
# Text: 3.
#
# Path: //Document/L[73]/LI[3]/LBody
# Page: 112
# Text: Hold an open-ended discussion. This can be done in small groups. Ask one member of the group to record the key points.
#
# Path: //Document/L[73]/LI[4]/Lbl
# Page: 112
# Text: 4.
#
# Path: //Document/L[73]/LI[4]/LBody
# Page: 112
# Text: At midpoint, check for clarity and ask for key learnings from each group.
#
# Path: //Document/L[73]/LI[5]/Lbl
# Page: 112
# Text: 5.
#
# Path: //Document/L[73]/LI[5]/LBody
# Page: 112
# Text: Identify sub-topics on these key learnings. Frame the remaining discussion around the subtopics. Invite participants to move groups if they wish to focus on one particular topic. Ask one participant to record the key points.
#
# Path: //Document/L[73]/LI[6]/Lbl
# Page: 112
# Text: 6.
#
# Path: //Document/L[73]/LI[6]/LBody
# Page: 112
# Text: Use the records of key points discussed to prepare a final report.
#
# Path: //Document/P[388]/StyleSpan/Reference
# Page: 112
# Text: Future Cities Dialogue
#
# Path: //Document/P[388]
# Page: 112
# Text: See , Forum for the Future (2012)
#
# Path: //Document/H2[100]
# Page: 112
# Text: Futures Wheel
#
# Path: //Document/P[389]
# Page: 112
# Text: The Futures Wheel is a form of structured brainstorming that helps participants visualize how important trends or events might impact on the policy or strategy area in question. It is particularly useful for identifying and mapping connections and causalities.
#
# Path: //Document/P[390]
# Page: 112
# Text: A strategically important trend or event – Brexit, for example – is placed at the centre of the futures wheel. Participants build the ‘spokes’ of the wheel by identifying the direct (‘first order’) consequences of that event. The first order consequences for Brexit might be ‘the UK pursues increased trade with countries outside Europe’, ‘migration falls’ and ‘foreign national health professionals and research staff move to mainland Europe’.
#
# Path: //Document/Figure[51]
# Page: 112
#
# Path: //Document/Figure[51]
# Page: 112
# Text: Trend or event
#
# Path: //Document/P[391]
# Page: 112
# Text: The group continues to build out along the spokes of the wheel. A second order consequence for ‘foreign national health professionals and research staff move to mainland Europe’ might be that ‘universities increase recruitment to medical school.’  A second order consequence for ‘the UK pursues increased trade with countries outside Europe’ might be that ‘the UK strengthens export agency presence in strategic territories.’
#
# Path: //Document/P[392]
# Page: 112
# Text: Three, or maybe four, orders of consequence are normally enough for one trend or event. Participants should look for cross connections between ’spokes’ as well.
#
# Path: //Document/P[393]/StyleSpan/Reference
# Page: 112
# Text: Clearer Thinking
#
# Path: //Document/P[393]
# Page: 112
# Text: See  (2015)
#
# Path: //Document/H2[101]
# Page: 113
# Text: Gaming
#
# Path: //Document/P[394]
# Page: 113
# Text: Gaming invites workshop participants to role play different stakeholder groups in different scenarios to understand how those groups will respond in the future. It is particularly effective in helping policy makers gain insight into the challenges faced by stakeholders.
#
# Path: //Document/P[395]
# Page: 113
# Text: Gaming involves getting participants to use information to make decisions about the future, in a controlled, risk-free environment. It can be used to develop alternative perspectives of the future, or to test the strengths and weaknesses of policy or strategy against a future vision or scenario set.
#
# Path: //Document/P[396]
# Page: 113
# Text: The technique is particularly effective if participants role play – that is, if government staff play the role of businesses, if business play the role of third sector and if third sector participants play the role of government (for example).
#
# Path: //Document/P[397]
# Page: 113
# Text: There are 6 steps:
#
# Path: //Document/L[74]/LI/Lbl
# Page: 113
# Text: 1.
#
# Path: //Document/L[74]/LI/LBody
# Page: 113
# Text: Introduce an existing scenario to participants.
#
# Path: //Document/L[74]/LI[2]/Lbl
# Page: 113
# Text: 2.
#
# Path: //Document/L[74]/LI[2]/LBody
# Page: 113
# Text: Assign roles to groups or individuals. Assign overall aims for each role (if desired).
#
# Path: //Document/L[74]/LI[3]/Lbl
# Page: 113
# Text: 3.
#
# Path: //Document/L[74]/LI[3]/LBody
# Page: 113
# Text: Each group reviews the strengths and weaknesses of the scenario from the perspective of their stakeholder group.
#
# Path: //Document/L[74]/LI[4]/Lbl
# Page: 113
# Text: 4.
#
# Path: //Document/L[74]/LI[4]/LBody
# Page: 113
# Text: Each group then identifies how their stakeholder group will respond to the scenario (making strategic choices that are relevant to the objectives of the policy area).
#
# Path: //Document/L[74]/LI[5]/Lbl
# Page: 113
# Text: 5.
#
# Path: //Document/L[74]/LI[5]/LBody
# Page: 113
# Text: Make recommendations for policy based on the conversation.
#
# Path: //Document/L[74]/LI[6]/Lbl
# Page: 113
# Text: 6.
#
# Path: //Document/L[74]/LI[6]/LBody
# Page: 113
# Text: Repeat with other scenarios as required.
#
# Path: //Document/P[398]/StyleSpan/Reference
# Page: 113
# Text: Cyber Trust and Crime Prevention: Gaining Insight for Three
#
# Path: //Document/P[398]/StyleSpan/Reference[2]
# Page: 113
# Text: Different Futures
#
# Path: //Document/P[398]
# Page: 113
# Text: See GO-Sciences Foresight report on  (2004)
#
# Path: //Document/H2[102]
# Page: 113
# Text: Morphological Analysis
#
# Path: //Document/P[399]
# Page: 113
# Text: Morphological Analysis is a technique for building understanding of the deep structure and relationships between different domains in the project area.
#
# Path: //Document/P[400]
# Page: 113
# Text: The approach involves breaking a complex problem down into its main component parts and looking for ways to combine them to create innovative approaches or solve existing challenges. Some combinations may already exist and others may not be possible or appropriate; but the remaining ones may represent new ideas for tackling the problem.
#
# Path: //Document/P[401]
# Page: 113
# Text: There are 6 steps:
#
# Path: //Document/L[75]/LI/Lbl
# Page: 113
# Text: 1.
#
# Path: //Document/L[75]/LI/LBody
# Page: 113
# Text: Agree the problem to be analysed.
#
# Path: //Document/L[75]/LI[2]/Lbl
# Page: 113
# Text: 2.
#
# Path: //Document/L[75]/LI[2]/LBody
# Page: 113
# Text: Identify and define the relevant issues (parameters) involved.
#
# Path: //Document/L[75]/LI[3]/Lbl
# Page: 113
# Text: 3.
#
# Path: //Document/L[75]/LI[3]/LBody
# Page: 113
# Text:  For each parameter, identify the key component parts.
#
# Path: //Document/L[75]/LI[4]/Lbl
# Page: 113
# Text: 4.
#
# Path: //Document/L[75]/LI[4]/LBody
# Page: 113
# Text: Create a series of grids that juxtapose the component parts of one parameter horizontally against the component parts of a second parameter vertically.
#
# Path: //Document/L[75]/LI[5]/Lbl
# Page: 113
# Text: 5.
#
# Path: //Document/L[75]/LI[5]/LBody
# Page: 113
# Text: Use the grid to combine component parts.
#
# Path: //Document/L[75]/LI[6]/Lbl
# Page: 113
# Text: 6.
#
# Path: //Document/L[75]/LI[6]/LBody
# Page: 113
# Text: 6. Identify the combinations that create new opportunities and new approaches.
#
# Path: //Document/P[402]/StyleSpan/Reference
# Page: 113
# Text: General Morphological Analysis
#
# Path: //Document/P[402]
# Page: 113
# Text: See  (2013)
#
# Path: //Document/H1[21]
# Page: 114
# Text: Annex 7: Further reading
#
# Path: //Document/P[403]/StyleSpan/Reference
# Page: 114
# Text: Foresight Projects Page
#
# Path: //Document/P[403]
# Page: 114
# Text: Perhaps the single most useful source of further reading is GO-Science’s which lists past Foresight projects. Most of the techniques included in the Toolkit are to be found amongst them.
#
# Path: //Document/P[404]
# Page: 114
# Text: There is a growing body of literature on the theory, application and impact of futures thinking and foresight and there are links here to some key resources. There are also links to some sources of trends analysis, although it is worth noting that trends analysis is most effective when done on a project by project basis.
#
# Path: //Document/H2[103]
# Page: 114
# Text: Trends analysis
#
# Path: //Document/P[405]/StyleSpan/Reference
# Page: 114
# Text: Global Strategic Trends out to 2045
#
# Path: //Document/P[405]
# Page: 114
# Text: , Development, Concepts and Doctrine Centre, Ministry of Defence (2014):
#
# Path: //Document/P[406]/StyleSpan/Reference
# Page: 114
# Text: Global Megatrends
#
# Path: //Document/P[406]
# Page: 114
# Text: , European Environment Agency (2017)
#
# Path: //Document/P[407]/StyleSpan/Reference
# Page: 114
# Text: Horizon Scan of Megatrends and Technology Trends in the Context of Future Research Policy
#
# Path: //Document/P[407]
# Page: 114
# Text: OECD (2016)
#
# Path: //Document/P[408]/StyleSpan/Reference
# Page: 114
# Text: Global Trends: Challenges and Opportunities in the Implementation of the Sustainable
#
# Path: //Document/P[408]/StyleSpan/Reference[2]
# Page: 114
# Text: Development Goals
#
# Path: //Document/P[408]
# Page: 114
# Text:  (UNDP, 2017)
#
# Path: //Document/P[409]
# Page: 114
# Text: GO-Science: Internal Horizon Scanning (2017)
#
# Path: //Document/H2[104]
# Page: 114
# Text: Books on scenario thinking
#
# Path: //Document/P[410]/StyleSpan/Reference
# Page: 114
# Text: Learnings from the Long View
#
# Path: //Document/P[410]
# Page: 114
# Text: , Peter Schwartz (2011)
#
# Path: //Document/P[411]/StyleSpan/Reference
# Page: 114
# Text: Thinking about the Future: Guidelines for Strategic Foresight
#
# Path: //Document/P[411]
# Page: 114
# Text: , Andy Hines and Peter Bishop (2015)
#
# Path: //Document/P[412]/StyleSpan/Reference
# Page: 114
# Text: Transformative Scenario Planning: Working Together to Change the Future
#
# Path: //Document/P[412]
# Page: 114
# Text: , Adam Kahane and Kees van der Heijden (2012)
#
# Path: //Document/H2[105]
# Page: 114
# Text: Books on Facilitation
#
# Path: //Document/P[413]/StyleSpan/Reference
# Page: 114
# Text: Unlocking the Magic of Facilitation: 11 Key Concepts You Didn’t Know You Didn’t Know
#
# Path: //Document/P[413]
# Page: 114
# Text: , Sam Killerman and Meg Bolger (2016)
#
# Path: //Document/P[414]/StyleSpan/Reference
# Page: 114
# Text: The Skilled Facilitator: A Comprehensive Resource for Consultants, Facilitators, Coaches, and
#
# Path: //Document/P[414]/StyleSpan/Reference[2]
# Page: 114
# Text: Trainers
#
# Path: //Document/P[414]
# Page: 114
# Text: , Roger M Schwartz (2016)
#
# Path: //Document/H2[106]
# Page: 114
# Text: Case studies from applying Futures Thinking and Foresight techniques
#
# Path: //Document/P[415]/StyleSpan/Reference
# Page: 114
# Text: Models of Horizon Scanning: How to integrate Horizon Scanning into European Research and
#
# Path: //Document/P[415]/StyleSpan/Reference[2]
# Page: 114
# Text: Innovation policies
#
# Path: //Document/P[415]
# Page: 114
# Text: , Fraunhofer Institute for Systems and Innovation (2015)
#
# Path: //Document/P[416]/StyleSpan/Reference
# Page: 114
# Text: A 2017 Horizon Scan of Emerging Issues for Global Conservation and Biological Diversity
#
# Path: //Document/P[416]
# Page: 114
# Text: Sutherand et al (2017)
#
# Path: //Document/P[417]/StyleSpan/Reference
# Page: 114
# Text: Horizon Scanning: Enhancing Strategic Insight for National Security policy making
#
# Path: //Document/P[417]
# Page: 114
# Text: , David Connery, (2013) Security Challenges, Vol 9, pp 11-30
#
# Path: //Document/H2[107]
# Page: 115
# Text: Futures techniques
#
# Path: //Document/P[418]/StyleSpan/Reference
# Page: 115
# Text: An Introduction to Corporate Foresight
#
# Path: //Document/P[418]
# Page: 115
# Text: , Arup
#
# Path: //Document/P[419]/StyleSpan/Reference
# Page: 115
# Text: Foresight, The Manual
#
# Path: //Document/P[419]
# Page: 115
# Text:  UNDP Global Centre for Public Excellence

# %%
# data structures for the entire PDF that include structural metadata along with text

@dataclass
class InterimElement:
    """Represent an element in the document that is about to be processed"""

    raw: Dict[str, Any]
    """JSON object from the Adobe Extract API"""
    is_aside: bool
    """Whether the element is an aside (elements that are next to a table or a figure)"""
    path: str
    """The path of the element in the document without the //Document prefix and other useless parts"""

    @property
    def text(self) -> Optional[str]:
        """The text of the element"""
        # Preprocess
        if result := self.raw.get("Text"):
            # Remove 3x or more consecutive underscores or dots
            result = re.sub(r"(\_|\.){3,}", "", result)
            # Remove trailing whitespace
            result = result.rstrip()
            # Check if is numeric or is digit and return None if so
            if result.isnumeric() or result.isdigit():
                return None
            # Remove empty paragraphs
            if result == "" or result == "\n":
                return None

            return result
        else:
            return None

    @property
    def page(self) -> Optional[int]:
        """The page of the element"""
        return self.raw.get("Page")

    @property
    def full_path(self) -> Optional[str]:
        """The full path of the element in the document as provided by Adobe Extract API"""
        return self.raw.get("Path")

class TextOrigin(StrEnum):
    """Enumeration to describe the origin of a text"""

    TOC = "TOC"
    """Table of contents"""
    PARAGRAPH = "PARAGRAPH"
    LIST = "LIST"
    TABLE = "TABLE"
    FIGURE = "FIGURE"

class Paragraph:
    """Describe a paragraph of text"""

    def __init__(self, text: str, origin: TextOrigin, aside: bool = False) -> None:
        """
        Args:
            text (str): The text of the paragraph
            origin (TextOrigin): The origin of the text in this paragraph
            aside (bool, optional): Whether the paragraph is an aside (elements that are next to a table or a figure).
                                     Defaults to `False`.
        """
        self.text = text
        self.origin = origin
        self.aside = aside

    def __repr__(self) -> str:
        return f"<Paragraph ({self.origin}) text={self.text}>"

class Section:
    """Describe a section of the document. Separated and detected by Adobe Extract API by headers (H1, H2, ..., Hn)."""

    def __init__(self, title: Optional[str] = None, pages: Optional[Set[int]] = None, section_type: Optional[str] = None, paragraphs: Optional[List[str]] = None, subsections: Optional[List["Section"]] = None, parent: Optional["Section"] = None) -> None:
        self.title = title
        self.pages = pages if pages else set()
        self.section_type = section_type
        self.paragraphs = paragraphs if paragraphs else []
        self.parent: Optional[weakref.ReferenceType[Section]] = weakref.ref(parent) if parent else None
        self.subsections: List[Section] = subsections if subsections else []

    def __repr__(self) -> str:
        return f"<Section ({self.section_type}) title={self.title}>"

class Document(Section):
    """A tree of Sections"""

    def __init__(self, title: str | None = None, pages: Set[int] = set(), paragraphs: List[str] = [], subsections: List[Section] = [], parent: Section | None = None) -> None:
        super().__init__(title, pages, "document", paragraphs, subsections, parent)


def adobe_extracted_pdf_to_document(extracted_pdf: AdobeExtractedPDF) -> Document:
    # header_to_section_type = {
    #     "H1": "section",
    #     "H2": "subsection",
    #     "H3": "subsubsection",
    # }
    document = Document()

    curr_section = document
    section_to_insert_header = {}
    elements_iterator = iter(extracted_pdf.json_data["elements"])
    elements_stack: List[Tuple[dict, str]] = []

    def get_next_elem() -> InterimElement:
        """Uses an iterator (and a stack) to get the next element from the structured_json"""
        if elements_stack:
            return elements_stack.pop()
        else:
            element = next(elements_iterator)
            path = element.get("Path")
            if path is None:
                raise ValueError("Path is None")

            # Verify that xpath starts with //Document
            if not path.startswith("//Document"):
                raise ValueError(f"Path does not start with //Document: {path}")

            # Remove //Document
            path = path.replace("//Document", "", 1)

            # Check if it is an Aside element
            is_aside = False
            new_path, n_occurences = re.subn(r"^\/Aside(\[\d+\])?", "", path)
            if n_occurences == 1:
                # remove Aside prefix
                path = new_path
                is_aside = True

            # Remove /Reference occurences
            new_path, n_occurences = re.subn(r"\/Reference(\[\d+\])?(\/Sub(\[\d+\])?)?", "", path)
            if n_occurences > 0:
                path = new_path

            # Remove /ParagraphSpan occurences
            new_path, n_occurences = re.subn(r"\/ParagraphSpan(\[\d+\])?", "", path)
            if n_occurences > 0:
                path = new_path

            # Remove /StyleSpan occurences
            new_path, n_occurences = re.subn(r"\/StyleSpan(\[\d+\])?", "", path)
            if n_occurences > 0:
                path = new_path

        return InterimElement(element, is_aside, path)

    def add_paragraph(paragraph: Paragraph, pages: Optional[Union[Set[int], int]]):
        if paragraph.text is not None:
            curr_section.paragraphs.append(paragraph)
            if pages:
                if isinstance(pages, int):
                    curr_section.pages.add(pages)
                elif isinstance(pages, set):
                    curr_section.pages.update(pages)

    try:
        while True:
            element = get_next_elem()

            if re.match(r".*\/(ExtraCharSpan|DirectEntrySpan)(\[\d+\])?$", element.path):
                # Skip extra characters
                continue
            elif re.match(r"^\/Title$", element.path):
                # Title
                document.title = element.text
            elif re.match(r"^(\/P(\[\d+\])?)?\/Figure(\[\d+\])?$", element.path):
                # Figure
                add_paragraph(Paragraph(element.text, TextOrigin.FIGURE), pages=element.page)
            elif re.match(r"^\/P(\[\d+\])?(\/(Sub|ParagraphSpan)(\[\d+\])?)?$", element.path):
                # Paragraph
                add_paragraph(Paragraph(element.text, TextOrigin.PARAGRAPH), pages=element.page)
            elif re.match(r"^\/Table(\[\d+\])?.*$", element.path):
                # Table
                if csv_paths := element.raw.get("filePaths"):
                    # Table with data
                    # load the csvs and add them as paragraphs
                    for csv_path in csv_paths:
                        csv_text = extracted_pdf.csv_tables[csv_path]
                        add_paragraph(Paragraph(csv_text, TextOrigin.TABLE), pages=element.page)

            elif match := re.match(r"^\/(H\d)(\[\d+\])?(\/Sub(\[\d+\])?)?$", element.path):
                # Header
                title = element.text
                section_type = match.group(1)

                # Verify that this header is not the same as the previous one
                # Check if page difference is less than 2
                # Check if title is the same
                if curr_section.title == title and element.page - max(curr_section.pages) < 2:
                    # Skip this header
                    continue

                # Verify next element is a paragraph and not a followup header
                while True:
                    next_element = get_next_elem()
                    reinsert_back = True
                    if next_match := re.match(r"^\/(H\d)(\[\d+\])?(\/Sub(\[\d+\])?)?$", next_element.path):
                        if next_match.group(1) == section_type:
                            next_title = next_element.text or ""
                            if not title.endswith(" ") and not next_title.startswith(" "):
                                title += " "
                            title += next_title
                            reinsert_back = False

                    if reinsert_back:
                        # Next element is not a header, push it to the stack
                        elements_stack.append(next_element)
                        break

                # Create new section
                new_section = Section(
                    title=title,
                    section_type=section_type,
                )

                # Check if new section is a subsection
                if curr_section.section_type == "document":
                    # New section is a top level (H1) section
                    # Add it to the document
                    curr_section.subsections.append(new_section)
                    # Set parent of new section to document
                    new_section.parent = curr_section
                    # Every new H1 has to be inserted into document subsections
                    section_to_insert_header[section_type] = curr_section
                else:
                    if section_type < curr_section.section_type:
                        # H2 -> H1 or H3 -> H2 or H3 -> H1
                        if parent_section := section_to_insert_header.get(section_type):
                            parent_section.subsections.append(new_section)
                            new_section.parent = parent_section
                        else:
                            # TODO: find closest parent of curr_section with section_type < new_section.section_type
                            raise ValueError("Could not find parent section")

                    elif section_type > curr_section.section_type:
                        # H1 -> H2 or H2 -> H3 or H1 -> H3
                        # curr_section is the parent
                        curr_section.subsections.append(new_section)
                        new_section.parent = curr_section
                        section_to_insert_header[section_type] = curr_section
                    else:
                        # H1 = H1 or H2 = H2 or H3 = H3
                        # curr_section.parent is the parent as they are on the same level
                        curr_section.parent.subsections.append(new_section)
                        new_section.parent = curr_section.parent

                curr_section = new_section
            elif match := re.match(r"^\/L(\[\d+\])?\/LI(\[\d+\])?\/(Lbl|LBody).*$", element.path):
                # List
                list_item_type = match.group(3)
                if list_item_type == "Lbl":
                    # Check if we can join it with a LBody element that should follow this one
                    next_element = get_next_elem()
                    if next_element.path == element.path.replace("Lbl", "LBody"):
                        # Join the two elements
                        joined_text = element.text or ""
                        if next_element.text:
                            if not next_element.text.startswith(" "):
                                joined_text += " "
                            joined_text += next_element.text
                        add_paragraph(Paragraph(joined_text, TextOrigin.LIST), pages=set([element.page, next_element.page]))
                    else:
                        # Push next element to stack
                        elements_stack.append(next_element)
                        # Add current element as a paragraph
                        add_paragraph(Paragraph(element.text, TextOrigin.LIST), pages=element.page)
                elif list_item_type == "LBody":
                    add_paragraph(Paragraph(element.text, TextOrigin.LIST), pages=element.page)
            elif match := re.match(r"^\/TOC(\[\d+\])?\/TOCI(\[\d+\])?\/(Span|Lbl|LBody)(\[\d+\])?$", element.path):
                # Table of contents
                toc_elem_type = match.group(3)
                if toc_elem_type == "Span":
                    if text := element.text:
                        # Check if the next element is another span that should be joined
                        next_element = get_next_elem()
                        if next_element.path == element.path + "[2]":
                            # Join the two elements
                            joined_text = text
                            if next_element.text:
                                if not next_element.text.startswith(" "):
                                    joined_text += " "
                                joined_text += next_element.text
                            add_paragraph(Paragraph(joined_text, TextOrigin.TOC), pages=set([element.page, next_element.page]))
                        else:
                            # Push next element to stack
                            elements_stack.append(next_element)
                            # Add current element as a paragraph
                            add_paragraph(Paragraph(text, TextOrigin.TOC), pages=element.page)
                elif toc_elem_type == "Lbl":
                    # Check if we can join it with a LBody element that should follow this one
                    next_element = get_next_elem()
                    if next_element.path == element.path.replace("Lbl", "LBody"):
                        # Join the two elements
                        joined_text = element.text or ""
                        if next_element.text:
                            if not next_element.text.startswith(" "):
                                joined_text += " "
                            joined_text += next_element.text
                        add_paragraph(Paragraph(joined_text, TextOrigin.TOC), pages=set([element.page, next_element.page]))
                    else:
                        # Push next element to stack
                        elements_stack.append(next_element)
                        # Add current element as a paragraph
                        add_paragraph(Paragraph(element.text, TextOrigin.TOC), pages=element.page)

            elif re.match(r"^\/Footnote(\[\d+\])?$", element.path):
                # Footnote
                # Ignore for now
                continue
            else:
                add_paragraph(Paragraph(element.text, TextOrigin.PARAGRAPH), pages=element.page)
                print(f"Unknown element path: {element.path} in {extracted_pdf.file_path}")
                #raise ValueError(f"Unknown element path: {element.path}")
    except StopIteration:
        pass

    return document

# %%
document = adobe_extracted_pdf_to_document(extracted_pdf)

# %%
# Sanity check
# Count number of sections per section type
counts = {}
def count_sections(section: Section):
    if section.section_type not in counts:
        counts[section.section_type] = 0
    counts[section.section_type] += 1
    for subsection in section.subsections:
        count_sections(subsection)
count_sections(document)
# Remove document count (always '1')
del counts["document"]

# Count number of sections in the JSON
json_section_counts = {}
for element in result["elements"]:
    if path := element.get("Path"):
        if match := re.match(r"^\/\/Document\/(H\d)(\[\d+\])?$", path):
            section_type = match.group(1)
            if section_type not in json_section_counts:
                json_section_counts[section_type] = 0
            json_section_counts[section_type] += 1

# Should be roughly the same
# (some headers might get merged into one header so the counts are not exactly the same)
# but this always holds: for each section: counts <= json counts
print(counts, json_section_counts)
# Out:
# {'H1': 21, 'H2': 98, 'H3': 47, 'H4': 18} {'H1': 21, 'H2': 107, 'H3': 56, 'H4': 18}

# %%
document.subsections
# Out:
# [<Section (H1) title=Contents>,
#  <Section (H1) title=1. Introduction>,
#  <Section (H1) title=2. Introduction to futures thinking>,
#  <Section (H1) title=3. Futures process design>,
#  <Section (H1) title=4. Using the toolkit>,
#  <Section (H1) title=5. Pathways designed to meet specific business needs>,
#  <Section (H1) title=6. Tools for gathering intelligence about the future>,
#  <Section (H1) title=7. Tools for exploring the dynamics of change>,
#  <Section (H1) title=8. Tools for describing what the future might be like>,
#  <Section (H1) title=9. Tools for developing and testing policy and strategy>,
#  <Section (H1) title=10 minutes>,
#  <Section (H1) title=Annex 1: Sample futures and foresight material>,
#  <Section (H1) title=Two horizon scanning formats>,
#  <Section (H1) title=An extract from an issues paper>,
#  <Section (H1) title=A sample scenario (one from a group of four)>,
#  <Section (H1) title=Annex 2: Glossary of futures and foresight terms>,
#  <Section (H1) title=Annex 3: Frequently Asked Questions>,
#  <Section (H1) title=Annex 4: Introducing metrics into scenario thinking>,
#  <Section (H1) title=Annex 5: Case Studies>,
#  <Section (H1) title=Annex 6: Wider set of futures tools>,
#  <Section (H1) title=Annex 7: Further reading>]

# %%
# Create a simple linear text representation of the document
def document_to_text(document: Document) -> str:
    text = ""
    for paragraph in document.paragraphs:
        text += paragraph.text + "\n"
    for subsection in document.subsections:
        text += subsection.title + "\n"
        text += document_to_text(subsection)
    return text

document_text = document_to_text(document)

# %%
# write document_text to processed dir
output_basename = Path(input_pdf).stem + ".txt"
output_dir = "../../data/processed/adobe-extract/"

# create dir if not exists
os.makedirs(output_dir, exist_ok=True)

with open(os.path.join(output_dir, output_basename), "w") as f:
    f.write(document_text)

print(f"Processed file: {input_pdf}")
# Out:
# Processed file: UK_23.pdf

# %%
document.subsections[4].subsections[0].paragraphs
# Out:
# [<Paragraph (PARAGRAPH) text=The Toolkit contains 12 tools, organized into four categories and described in detail in the relevant chapter.>,
#  <Paragraph (PARAGRAPH) text=There are four tools for gathering intelligence about the future ➲ Chapter 6>,
#  <Paragraph (LIST) text=• Horizon Scanning>,
#  <Paragraph (LIST) text=• 7 Questions>,
#  <Paragraph (LIST) text=• The Issues Paper>,
#  <Paragraph (LIST) text=• Delphi>,
#  <Paragraph (TABLE) text=There are two tools for exploring the dynamics of change  • Driver Mapping   • Axes of Uncertainty    ,➲  Chapter 7  >,
#  <Paragraph (PARAGRAPH) text=There are three tools for describing what the future might be like>,
#  <Paragraph (LIST) text=• Scenarios>,
#  <Paragraph (LIST) text=• Visioning>,
#  <Paragraph (LIST) text=• SWOT Analysis>,
#  <Paragraph (PARAGRAPH) text=There are three tools for developing and testing policy and strategy>,
#  <Paragraph (LIST) text=• Policy Stress-testing>,
#  <Paragraph (LIST) text=• Backcasting>,
#  <Paragraph (LIST) text=• Roadmapping>,
#  <Paragraph (LIST) text=➲>,
#  <Paragraph (LIST) text= Chapter 8>,
#  <Paragraph (LIST) text=➲>,
#  <Paragraph (LIST) text= Chapter 9>,
#  <Paragraph (PARAGRAPH) text=The tools are summarised in the tables on pages 9 to 12. The relationship between the different categories is presented graphically in the icon map on page 13.>,
#  <Paragraph (PARAGRAPH) text=The Toolkit also contains 7 pathways – tools combined in particular ways to meet specific business needs. The pathways are set out in Chapter 5.>,
#  <Paragraph (PARAGRAPH) text=The final two sections of this chapter introduce the guidance notes for facilitators and the navigation flags.>]

# %%
input_pdfs = [f"UK_{i:02}.pdf" for i in range(26, 45)]


for input_pdf in input_pdfs:
    try:
        # Get AdobeExtractedPDF
        extracted_pdf = get_extracted_pdf(input_file_path=os.path.join(input_pdf_dir, input_pdf))
        # Convert to document
        document = adobe_extracted_pdf_to_document(extracted_pdf)
        # Convert to text
        document_text = document_to_text(document)

        # write document_text to processed dir
        output_basename = Path(input_pdf).stem + ".txt"
        output_dir = "../../data/processed/adobe-extract/"

        # create dir if not exists
        os.makedirs(output_dir, exist_ok=True)

        with open(os.path.join(output_dir, output_basename), "w") as f:
            f.write(document_text)

        print(f"Processed file: {input_pdf}")
    except ServiceUsageException as e:
        print("Service usage error: " + input_pdf)
        print(e)
        continue
    except ServiceApiException as e:
        print("Bad input file: " + input_pdf)
        print(e)
        continue
    except Exception as e:
        print("Failed to process file: " + input_pdf)
        raise e
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb Cell 16 line 7
#       <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> for input_pdf in input_pdfs:
#       <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     try:
#       <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>         # Get AdobeExtractedPDF
# ----> <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>         extracted_pdf = get_extracted_pdf(input_file_path=os.path.join(input_pdf_dir, input_pdf))
#       <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>         # Convert to document
#       <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>         document = adobe_extracted_pdf_to_document(extracted_pdf)
#
# /Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb Cell 16 line 5
#      <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=47'>48</a> extract_pdf_operation.set_options(extract_pdf_options)
#      <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=49'>50</a> # Execute the operation.
# ---> <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=50'>51</a> result: FileRef = extract_pdf_operation.execute(execution_context)
#      <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=52'>53</a> # Save the result to the specified location.
#      <a href='vscode-notebook-cell:/Users/dvdblk/Documents/Code/_projects/hack4good-oecd/experiments/alex/adobe-extract-parser.ipynb#X14sZmlsZQ%3D%3D?line=53'>54</a> result.save_as(zip_file)
#
# File ~/miniconda/envs/hack4good/lib/python3.11/site-packages/adobe/pdfservices/operation/pdfops/extract_pdf_operation.py:141, in ExtractPDFOperation.execute(self, execution_context)
#     138 self._logger.info("All validations successfully done. Beginning ExtractPDF operation execution")
#     140 x_request_id = str(uuid.uuid4())
# --> 141 download_uri = ExtractPDFService.extract_pdf(execution_context, self._source_file_ref, self.get_options(),
#     142                                              x_request_id)
#     144 file_location = get_temporary_destination_path(target_extension=ExtensionMediaTypeMapping.ZIP.extension)
#     145 file = StorageApi.download_and_save_file(execution_context, download_uri, file_location)
#
# File ~/miniconda/envs/hack4good/lib/python3.11/site-packages/adobe/pdfservices/operation/internal/service/extract_pdf_service.py:38, in ExtractPDFService.extract_pdf(context, source_file_ref, extract_pdf_options, x_request_id)
#      34 extract_pdf_request = ExtractPDFRequest.from_extract_pdf_options(asset_id, extract_pdf_options)
#      35 location = PlatformApi.submit_job(context, extract_pdf_request, ServiceConstants.EXTRACT_OPERATION_ENDPOINT,
#      36                                   x_request_id, ServiceConstants.EXTRACT_OPERATION_NAME)
# ---> 38 status_poll_response = PlatformApi.status_poll(context, location, x_request_id)
#      39 download_uri = json.loads(status_poll_response.content).get('resource').get('downloadUri')
#      40 return download_uri
#
# File ~/miniconda/envs/hack4good/lib/python3.11/site-packages/adobe/pdfservices/operation/internal/api/platform_api.py:80, in PlatformApi.status_poll(context, location, x_request_id)
#      70 http_request = HttpRequest(http_method=HttpMethod.GET,
#      71                            request_key=RequestKey.STATUS,
#      72                            url=location,
#    (...)
#      76                            read_timeout=context.client_config.get_read_timeout(),
#      77                            retryable=True)
#      79 try:
# ---> 80     response = polling2.poll(
#      81         lambda: http_client.process_request(http_request=http_request,
#      82                                             success_status_codes=[HTTPStatus.OK, HTTPStatus.ACCEPTED],
#      83                                             error_response_handler=PlatformApi.handle_error_response),
#      84         check_success=is_correct_response,
#      85         step=0.5,
#      86         timeout=10 * 60
#      87     )
#      88     logging.debug(f'Total polling time, Latency(ms): {(datetime.now() - start_time).microseconds / 1000}')
#      89     return response
#
# File ~/miniconda/envs/hack4good/lib/python3.11/site-packages/polling2.py:217, in poll(target, step, args, kwargs, timeout, max_tries, check_success, step_function, ignore_exceptions, poll_forever, collect_values, log, log_error)
#     214 if timeout is not None and time.time() >= timeout:
#     215     raise TimeoutException(values, last_item)
# --> 217 time.sleep(step)
#     218 step = step_function(step)
#
# KeyboardInterrupt:
